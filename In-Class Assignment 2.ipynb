# %% [markdown]
# # Data Manipulation using Python - Pandas

# %% [markdown]
# Name: Kongphop Wichaidit

# %%
#import pandas
import pandas as pd

# %% [markdown]
# 1. Read 'Housing.csv' file

# %%
data_csv = pd.read_csv(r'C:\Users\kongp\Documents\GitHub\Basic_Pandas\Housing.csv')

data_csv
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0        79545.45857             5.682861                   7.009188
# 1        79248.64245             6.002900                   6.730821
# 2        61287.06718             5.865890                   8.512727
# 3        63345.24005             7.188236                   5.586729
# 4        59982.19723             5.040555                   7.839388
# 5                NaN             4.988408                   6.104512
# 6        64698.46343             6.025336                   8.147760
# 7        78394.33928             6.989780                   6.620478
# 8        59927.66081             5.362126                   6.393121
# 9        81885.92718             4.423672                   8.167688
# 10       80527.47208             8.093513                   5.042747
# 11       50593.69550             4.496513                   7.467627
# 12       39033.80924             7.671755                   7.250029
# ...

# %% [markdown]
# 2. Print the first 5 rows of the data from 'Housing.csv' file

# %%
data_csv.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                           NaN      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# 3. Find the shape of the dataframe

# %%
data_csv.shape
# Out:
# (20, 7)

# %% [markdown]
# 4. Check for missing values

# %%
data_csv.isnull
# Out:
# <bound method DataFrame.isnull of     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0        79545.45857             5.682861                   7.009188
# 1        79248.64245             6.002900                   6.730821
# 2        61287.06718             5.865890                   8.512727
# 3        63345.24005             7.188236                   5.586729
# 4        59982.19723             5.040555                   7.839388
# 5                NaN             4.988408                   6.104512
# 6        64698.46343             6.025336                   8.147760
# 7        78394.33928             6.989780                   6.620478
# 8        59927.66081             5.362126                   6.393121
# 9        81885.92718             4.423672                   8.167688
# 10       80527.47208             8.093513                   5.042747
# 11       50593.69550             4.496513                   7.467627
# ...

# %% [markdown]
# 5. Count total missing values at each column in DataFrame.

# %%
data_csv.isnull().sum()
# Out:
# Avg. Area Income                1
# Avg. Area House Age             1
# Avg. Area Number of Rooms       1
# Avg. Area Number of Bedrooms    2
# Area Population                 1
# Price                           1
# Address                         0
# dtype: int64

# %% [markdown]
# 6. Permanently replace all missing values with 0

# %%
data_csv = data_csv.fillna(0)

# %%
data_csv
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0        79545.45857             5.682861                   7.009188
# 1        79248.64245             6.002900                   6.730821
# 2        61287.06718             5.865890                   8.512727
# 3        63345.24005             7.188236                   5.586729
# 4        59982.19723             5.040555                   7.839388
# 5            0.00000             4.988408                   6.104512
# 6        64698.46343             6.025336                   8.147760
# 7        78394.33928             6.989780                   6.620478
# 8        59927.66081             5.362126                   6.393121
# 9        81885.92718             4.423672                   8.167688
# 10       80527.47208             8.093513                   5.042747
# 11       50593.69550             4.496513                   7.467627
# 12       39033.80924             7.671755                   7.250029
# ...

# %% [markdown]
# 7. Permanently remove column 'Address'

# %%
del data_csv["Address"]

# %%
data_csv
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0        79545.45857             5.682861                   7.009188
# 1        79248.64245             6.002900                   6.730821
# 2        61287.06718             5.865890                   8.512727
# 3        63345.24005             7.188236                   5.586729
# 4        59982.19723             5.040555                   7.839388
# 5            0.00000             4.988408                   6.104512
# 6        64698.46343             6.025336                   8.147760
# 7        78394.33928             6.989780                   6.620478
# 8        59927.66081             5.362126                   6.393121
# 9        81885.92718             4.423672                   8.167688
# 10       80527.47208             8.093513                   5.042747
# 11       50593.69550             4.496513                   7.467627
# 12       39033.80924             7.671755                   7.250029
# ...

# %% [markdown]
# 8. Select rows with 'Avg. Area Number of Bedrooms' >4

# %%
data_csv[data_csv["Avg. Area Number of Bedrooms"] > 4]
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0        79545.45857             5.682861                   7.009188
# 2        61287.06718             5.865890                   8.512727
# 5            0.00000             4.988408                   6.104512
# 9        81885.92718             4.423672                   8.167688
# 10       80527.47208             8.093513                   5.042747
# 11       50593.69550             4.496513                   7.467627
# 14       69391.38018             0.000000                   8.406418
# 15       73091.86675             5.443156                   8.517513
# 18       63508.19430             5.947165                   7.187774
# 19       62085.27640             5.739411                   0.000000
#
#     Avg. Area Number of Bedrooms  Area Population         Price
# 0                           4.09      23086.80050  1.059034e+06
# 2                           5.13      36882.15940  1.058988e+06
# ...

# %% [markdown]
# 9. Sort the Data by 'Price'

# %%
data_csv.sort_values(by="Price")
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 16       79706.96306             5.067890                   8.219771
# 17       61929.07702             4.788550                   5.097010
# 4        59982.19723             5.040555                   7.839388
# 11       50593.69550             4.496513                   7.467627
# 8        59927.66081             5.362126                   6.393121
# 18       63508.19430             5.947165                   7.187774
# 19       62085.27640             5.739411                   0.000000
# 12       39033.80924             7.671755                   7.250029
# 2        61287.06718             5.865890                   8.512727
# 0        79545.45857             5.682861                   7.009188
# 5            0.00000             4.988408                   6.104512
# 3        63345.24005             7.188236                   5.586729
# 13       73163.66344             6.919535                   5.993188
# ...

# %% [markdown]
# 10. Export the DataFrame to a new csv file, use your first name as the file name (firstname.csv)

# %%
data_csv.to_csv("Kongphop.csv",index=0)
